# %%
# Use the citipy module to determine city based on latitude and longitude.
# Import the random module.
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
import requests as req
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
from datetime import datetime
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=23d253fbabc0aa0c36062c77d3993ed8

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
   
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.#
    try:
        # Parse the JSON and retrieve data.
        city_weather = req.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto ayora
# Processing Record 2 of Set 1 | faanui
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | new norfolk
# Processing Record 5 of Set 1 | umm kaddadah
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | miles city
# Processing Record 8 of Set 1 | praya
# Processing Record 9 of Set 1 | te anau
# Processing Record 10 of Set 1 | chimbote
# Processing Record 11 of Set 1 | kenai
# Processing Record 12 of Set 1 | labuhan
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | kimbe
# Processing Record 15 of Set 1 | souillac
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 1 | punta arenas
# Processing Record 20 of Set 1 | san patricio
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | spring hill
# Processing Record 23 of Set 1 | mehamn
# Processing Record 24 of Set 1 | mount isa
# Processing Record 25 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 1 | karatau
# Processing Record 27 of Set 1 | ardakan
# Processing Record 28 of Set 1 | catalina
# Processing Record 29 of Set 1 | preeceville
# Processing Record 30 of Set 1 | beloha
# Processing Record 31 of Set 1 | partizanskoye
# Processing Record 32 of Set 1 | lorengau
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 1 | pangody
# Processing Record 36 of Set 1 | charters towers
# Processing Record 37 of Set 1 | tambun
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | clyde river
# Processing Record 41 of Set 1 | ribeira grande
# Processing Record 42 of Set 1 | saint-philippe
# Processing Record 43 of Set 1 | georgetown
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | raudeberg
# Processing Record 46 of Set 1 | port alfred
# Processing Record 47 of Set 1 | opuwo
# Processing Record 48 of Set 1 | alyangula
# Processing Record 49 of Set 1 | teguise
# Processing Record 50 of Set 1 | tasiilaq
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | saraj
# Processing Record 3 of Set 2 | neiafu
# Processing Record 4 of Set 2 | lavrentiya
# Processing Record 5 of Set 2 | barrow
# Processing Record 6 of Set 2 | barmer
# Processing Record 7 of Set 2 | gizo
# Processing Record 8 of Set 2 | trincomalee
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | dikson
# Processing Record 11 of Set 2 | atuona
# Processing Record 12 of Set 2 | wanaka
# Processing Record 13 of Set 2 | trapani
# Processing Record 14 of Set 2 | cherskiy
# Processing Record 15 of Set 2 | bichura
# Processing Record 16 of Set 2 | pevek
# Processing Record 17 of Set 2 | bara
# Processing Record 18 of Set 2 | melfi
# Processing Record 19 of Set 2 | dingle
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | saskylakh
# Processing Record 22 of Set 2 | netanya
# Processing Record 23 of Set 2 | alofi
# Processing Record 24 of Set 2 | matagami
# Processing Record 25 of Set 2 | iquique
# Processing Record 26 of Set 2 | sinnar
# Processing Record 27 of Set 2 | ostrovnoy
# Processing Record 28 of Set 2 | kuche
# City not found. Skipping...
# Processing Record 29 of Set 2 | rundu
# Processing Record 30 of Set 2 | halenkov
# Processing Record 31 of Set 2 | alice springs
# Processing Record 32 of Set 2 | kuala terengganu
# Processing Record 33 of Set 2 | ahipara
# Processing Record 34 of Set 2 | longyearbyen
# Processing Record 35 of Set 2 | cape town
# Processing Record 36 of Set 2 | orlik
# Processing Record 37 of Set 2 | necochea
# Processing Record 38 of Set 2 | severo-kurilsk
# Processing Record 39 of Set 2 | synya
# Processing Record 40 of Set 2 | flinders
# Processing Record 41 of Set 2 | balgazyn
# Processing Record 42 of Set 2 | mahebourg
# Processing Record 43 of Set 2 | kapuskasing
# Processing Record 44 of Set 2 | lodeynoye pole
# Processing Record 45 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 2 | coihaique
# Processing Record 47 of Set 2 | sandviken
# Processing Record 48 of Set 2 | port elizabeth
# Processing Record 49 of Set 2 | kruisfontein
# Processing Record 50 of Set 2 | yellowknife
# Processing Record 1 of Set 3 | katsuura
# Processing Record 2 of Set 3 | upernavik
# Processing Record 3 of Set 3 | jamestown
# Processing Record 4 of Set 3 | caravelas
# Processing Record 5 of Set 3 | ilulissat
# Processing Record 6 of Set 3 | vila velha
# Processing Record 7 of Set 3 | salamiyah
# Processing Record 8 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 3 | airai
# Processing Record 10 of Set 3 | luau
# Processing Record 11 of Set 3 | torbay
# Processing Record 12 of Set 3 | esperance
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 15 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 3 | mata
# Processing Record 17 of Set 3 | bathsheba
# Processing Record 18 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 3 | hofn
# Processing Record 20 of Set 3 | cartagena
# Processing Record 21 of Set 3 | yuanping
# Processing Record 22 of Set 3 | ushuaia
# Processing Record 23 of Set 3 | tuktoyaktuk
# Processing Record 24 of Set 3 | nizhniy ingash
# Processing Record 25 of Set 3 | hegang
# Processing Record 26 of Set 3 | lebu
# Processing Record 27 of Set 3 | fairbanks
# Processing Record 28 of Set 3 | raymondville
# Processing Record 29 of Set 3 | springfield
# Processing Record 30 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 3 | guiyang
# Processing Record 32 of Set 3 | talnakh
# Processing Record 33 of Set 3 | cockburn town
# Processing Record 34 of Set 3 | naze
# Processing Record 35 of Set 3 | dasoguz
# Processing Record 36 of Set 3 | vostok
# Processing Record 37 of Set 3 | port lincoln
# Processing Record 38 of Set 3 | bereda
# Processing Record 39 of Set 3 | cabo san lucas
# Processing Record 40 of Set 3 | ossora
# Processing Record 41 of Set 3 | klaksvik
# Processing Record 42 of Set 3 | gamba
# Processing Record 43 of Set 3 | sao joao da barra
# Processing Record 44 of Set 3 | remanso
# Processing Record 45 of Set 3 | arvika
# Processing Record 46 of Set 3 | pangnirtung
# Processing Record 47 of Set 3 | broome
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | fort nelson
# Processing Record 50 of Set 3 | tura
# Processing Record 1 of Set 4 | lompoc
# Processing Record 2 of Set 4 | stamsund
# City not found. Skipping...
# Processing Record 3 of Set 4 | asau
# Processing Record 4 of Set 4 | norman wells
# Processing Record 5 of Set 4 | sawakin
# Processing Record 6 of Set 4 | yumen
# Processing Record 7 of Set 4 | algiers
# Processing Record 8 of Set 4 | arlit
# Processing Record 9 of Set 4 | codrington
# Processing Record 10 of Set 4 | gardez
# Processing Record 11 of Set 4 | poum
# Processing Record 12 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 4 | hami
# Processing Record 14 of Set 4 | babol
# Processing Record 15 of Set 4 | ivanava
# Processing Record 16 of Set 4 | shitanjing
# Processing Record 17 of Set 4 | belyy yar
# Processing Record 18 of Set 4 | rocha
# Processing Record 19 of Set 4 | belomorsk
# Processing Record 20 of Set 4 | saint george
# Processing Record 21 of Set 4 | manitouwadge
# Processing Record 22 of Set 4 | kununurra
# Processing Record 23 of Set 4 | victoria
# Processing Record 24 of Set 4 | jiuquan
# Processing Record 25 of Set 4 | umm lajj
# Processing Record 26 of Set 4 | alta floresta
# Processing Record 27 of Set 4 | bethel
# Processing Record 28 of Set 4 | carnarvon
# Processing Record 29 of Set 4 | manoel urbano
# Processing Record 30 of Set 4 | bitkine
# Processing Record 31 of Set 4 | isangel
# Processing Record 32 of Set 4 | le port
# Processing Record 33 of Set 4 | carutapera
# Processing Record 34 of Set 4 | ukiah
# Processing Record 35 of Set 4 | mariakani
# Processing Record 36 of Set 4 | marzuq
# Processing Record 37 of Set 4 | akyab
# Processing Record 38 of Set 4 | huntingdon
# Processing Record 39 of Set 4 | mar del plata
# Processing Record 40 of Set 4 | bengkulu
# Processing Record 41 of Set 4 | chokurdakh
# Processing Record 42 of Set 4 | gurgan
# City not found. Skipping...
# Processing Record 43 of Set 4 | nikolskoye
# Processing Record 44 of Set 4 | hamilton
# Processing Record 45 of Set 4 | nanortalik
# Processing Record 46 of Set 4 | husavik
# Processing Record 47 of Set 4 | mataura
# Processing Record 48 of Set 4 | pozo colorado
# Processing Record 49 of Set 4 | hilo
# Processing Record 50 of Set 4 | madras
# Processing Record 1 of Set 5 | tucurui
# Processing Record 2 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 5 | kaabong
# Processing Record 4 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 5 | makushino
# Processing Record 6 of Set 5 | barstow
# Processing Record 7 of Set 5 | grand gaube
# Processing Record 8 of Set 5 | jumla
# Processing Record 9 of Set 5 | magadan
# Processing Record 10 of Set 5 | okhotsk
# Processing Record 11 of Set 5 | ajdabiya
# Processing Record 12 of Set 5 | ust-kuyga
# Processing Record 13 of Set 5 | tuatapere
# Processing Record 14 of Set 5 | romny
# Processing Record 15 of Set 5 | havre-saint-pierre
# Processing Record 16 of Set 5 | saa
# Processing Record 17 of Set 5 | chumikan
# Processing Record 18 of Set 5 | auki
# Processing Record 19 of Set 5 | faya
# Processing Record 20 of Set 5 | cidreira
# Processing Record 21 of Set 5 | provideniya
# Processing Record 22 of Set 5 | zhangye
# Processing Record 23 of Set 5 | udachnyy
# Processing Record 24 of Set 5 | khatanga
# Processing Record 25 of Set 5 | buckeye
# Processing Record 26 of Set 5 | byron bay
# Processing Record 27 of Set 5 | ndele
# Processing Record 28 of Set 5 | agua dulce
# Processing Record 29 of Set 5 | segou
# Processing Record 30 of Set 5 | san policarpo
# Processing Record 31 of Set 5 | gravdal
# Processing Record 32 of Set 5 | beringovskiy
# Processing Record 33 of Set 5 | bredasdorp
# Processing Record 34 of Set 5 | avarua
# Processing Record 35 of Set 5 | ust-nera
# Processing Record 36 of Set 5 | pafos
# Processing Record 37 of Set 5 | baykit
# Processing Record 38 of Set 5 | ferrol
# Processing Record 39 of Set 5 | sinnamary
# Processing Record 40 of Set 5 | giddalur
# Processing Record 41 of Set 5 | sangar
# Processing Record 42 of Set 5 | kumano
# Processing Record 43 of Set 5 | salta
# Processing Record 44 of Set 5 | vila franca do campo
# Processing Record 45 of Set 5 | changji
# Processing Record 46 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 5 | cap malheureux
# Processing Record 48 of Set 5 | mayna
# Processing Record 49 of Set 5 | iqaluit
# Processing Record 50 of Set 5 | geraldton
# Processing Record 1 of Set 6 | wenling
# Processing Record 2 of Set 6 | ekibastuz
# Processing Record 3 of Set 6 | ponta do sol
# Processing Record 4 of Set 6 | constitucion
# Processing Record 5 of Set 6 | saint-louis
# Processing Record 6 of Set 6 | luanda
# Processing Record 7 of Set 6 | araguaina
# Processing Record 8 of Set 6 | shingu
# Processing Record 9 of Set 6 | port blair
# Processing Record 10 of Set 6 | teahupoo
# Processing Record 11 of Set 6 | bitung
# Processing Record 12 of Set 6 | mahajanga
# Processing Record 13 of Set 6 | excelsior springs
# Processing Record 14 of Set 6 | yabassi
# Processing Record 15 of Set 6 | zary
# Processing Record 16 of Set 6 | kukuna
# Processing Record 17 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 6 | bobrovka
# Processing Record 19 of Set 6 | hakui
# Processing Record 20 of Set 6 | south river
# Processing Record 21 of Set 6 | walvis bay
# Processing Record 22 of Set 6 | viet tri
# Processing Record 23 of Set 6 | namibe
# Processing Record 24 of Set 6 | bogorodskoye
# Processing Record 25 of Set 6 | brae
# Processing Record 26 of Set 6 | deniliquin
# Processing Record 27 of Set 6 | aswan
# Processing Record 28 of Set 6 | cayenne
# Processing Record 29 of Set 6 | pervomayskiy
# Processing Record 30 of Set 6 | saldanha
# Processing Record 31 of Set 6 | saint-georges
# Processing Record 32 of Set 6 | bowen
# Processing Record 33 of Set 6 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 34 of Set 6 | urusha
# Processing Record 35 of Set 6 | diamantino
# Processing Record 36 of Set 6 | kielce
# Processing Record 37 of Set 6 | oyon
# Processing Record 38 of Set 6 | laguna
# Processing Record 39 of Set 6 | batemans bay
# Processing Record 40 of Set 6 | hermagor
# Processing Record 41 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 42 of Set 6 | peruibe
# Processing Record 43 of Set 6 | baiyin
# Processing Record 44 of Set 6 | kropotkin
# Processing Record 45 of Set 6 | sept-iles
# Processing Record 46 of Set 6 | vung tau
# Processing Record 47 of Set 6 | uarini
# Processing Record 48 of Set 6 | baracoa
# Processing Record 49 of Set 6 | adrar
# Processing Record 50 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 1 of Set 7 | tripoli
# Processing Record 2 of Set 7 | saint-pierre
# Processing Record 3 of Set 7 | kushmurun
# Processing Record 4 of Set 7 | hermanus
# Processing Record 5 of Set 7 | salem
# Processing Record 6 of Set 7 | rudbar
# Processing Record 7 of Set 7 | nemuro
# Processing Record 8 of Set 7 | namatanai
# Processing Record 9 of Set 7 | sao filipe
# Processing Record 10 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 7 | bambous virieux
# Processing Record 12 of Set 7 | manta
# Processing Record 13 of Set 7 | aasiaat
# Processing Record 14 of Set 7 | college
# Processing Record 15 of Set 7 | minab
# Processing Record 16 of Set 7 | kang
# Processing Record 17 of Set 7 | hasaki
# Processing Record 18 of Set 7 | is
# City not found. Skipping...
# Processing Record 19 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 20 of Set 7 | romitan
# Processing Record 21 of Set 7 | pisco
# Processing Record 22 of Set 7 | berlevag
# Processing Record 23 of Set 7 | portland
# Processing Record 24 of Set 7 | colomi
# Processing Record 25 of Set 7 | linfen
# Processing Record 26 of Set 7 | vao
# Processing Record 27 of Set 7 | bharatpur
# Processing Record 28 of Set 7 | bahia blanca
# Processing Record 29 of Set 7 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 7 | thermon
# City not found. Skipping...
# Processing Record 31 of Set 7 | yerbogachen
# Processing Record 32 of Set 7 | dudinka
# Processing Record 33 of Set 7 | lakhdenpokhya
# Processing Record 34 of Set 7 | smithville
# Processing Record 35 of Set 7 | avera
# Processing Record 36 of Set 7 | saint-augustin
# Processing Record 37 of Set 7 | guerrero negro
# Processing Record 38 of Set 7 | praia
# Processing Record 39 of Set 7 | sorkjosen
# Processing Record 40 of Set 7 | balykshi
# Processing Record 41 of Set 7 | yashan
# Processing Record 42 of Set 7 | hackettstown
# Processing Record 43 of Set 7 | lipari
# Processing Record 44 of Set 7 | hay river
# Processing Record 45 of Set 7 | passo de camaragibe
# Processing Record 46 of Set 7 | atkinson
# Processing Record 47 of Set 7 | taranagar
# Processing Record 48 of Set 7 | marsh harbour
# Processing Record 49 of Set 7 | inirida
# Processing Record 50 of Set 7 | ieud
# Processing Record 1 of Set 8 | bachaquero
# Processing Record 2 of Set 8 | tiksi
# Processing Record 3 of Set 8 | bella union
# Processing Record 4 of Set 8 | makakilo city
# Processing Record 5 of Set 8 | banfora
# Processing Record 6 of Set 8 | ortega
# Processing Record 7 of Set 8 | honiara
# Processing Record 8 of Set 8 | coulihaut
# City not found. Skipping...
# Processing Record 9 of Set 8 | rawson
# Processing Record 10 of Set 8 | oranjemund
# Processing Record 11 of Set 8 | lasa
# Processing Record 12 of Set 8 | bandarbeyla
# Processing Record 13 of Set 8 | bubaque
# Processing Record 14 of Set 8 | custodia
# Processing Record 15 of Set 8 | nouadhibou
# Processing Record 16 of Set 8 | hastings
# Processing Record 17 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 18 of Set 8 | kodinsk
# Processing Record 19 of Set 8 | luderitz
# Processing Record 20 of Set 8 | cori
# Processing Record 21 of Set 8 | abu kamal
# Processing Record 22 of Set 8 | remontnoye
# Processing Record 23 of Set 8 | verkh-usugli
# Processing Record 24 of Set 8 | rio cuarto
# Processing Record 25 of Set 8 | malynivka
# Processing Record 26 of Set 8 | namwala
# Processing Record 27 of Set 8 | grindavik
# Processing Record 28 of Set 8 | khovu-aksy
# Processing Record 29 of Set 8 | calvia
# Processing Record 30 of Set 8 | marawi
# Processing Record 31 of Set 8 | baruun-urt
# Processing Record 32 of Set 8 | kachug
# Processing Record 33 of Set 8 | mount gambier
# Processing Record 34 of Set 8 | cururupu
# Processing Record 35 of Set 8 | ornskoldsvik
# Processing Record 36 of Set 8 | twin falls
# Processing Record 37 of Set 8 | novosokolniki
# Processing Record 38 of Set 8 | quirinopolis
# Processing Record 39 of Set 8 | muros
# Processing Record 40 of Set 8 | heihe
# Processing Record 41 of Set 8 | ambilobe
# Processing Record 42 of Set 8 | mazatan
# Processing Record 43 of Set 8 | manjakandriana
# Processing Record 44 of Set 8 | la ronge
# Processing Record 45 of Set 8 | snasa
# Processing Record 46 of Set 8 | ganzhou
# Processing Record 47 of Set 8 | never
# Processing Record 48 of Set 8 | solovetskiy
# City not found. Skipping...
# Processing Record 49 of Set 8 | siirt
# Processing Record 50 of Set 8 | el viejo
# Processing Record 1 of Set 9 | chuy
# Processing Record 2 of Set 9 | axim
# Processing Record 3 of Set 9 | pedernales
# Processing Record 4 of Set 9 | okandja
# City not found. Skipping...
# Processing Record 5 of Set 9 | harper
# Processing Record 6 of Set 9 | port-de-paix
# City not found. Skipping...
# Processing Record 7 of Set 9 | aykhal
# Processing Record 8 of Set 9 | port augusta
# Processing Record 9 of Set 9 | westport
# Processing Record 10 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 11 of Set 9 | kaitangata
# Processing Record 12 of Set 9 | plouzane
# Processing Record 13 of Set 9 | sambava
# Processing Record 14 of Set 9 | tete
# Processing Record 15 of Set 9 | sucua
# Processing Record 16 of Set 9 | abadiania
# Processing Record 17 of Set 9 | norwich
# Processing Record 18 of Set 9 | bambanglipuro
# Processing Record 19 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 9 | nome
# Processing Record 21 of Set 9 | turbat
# Processing Record 22 of Set 9 | yar-sale
# Processing Record 23 of Set 9 | rovaniemi
# Processing Record 24 of Set 9 | aklavik
# Processing Record 25 of Set 9 | hualmay
# Processing Record 26 of Set 9 | odweyne
# Processing Record 27 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 28 of Set 9 | san pedro
# Processing Record 29 of Set 9 | komsomolskiy
# Processing Record 30 of Set 9 | inongo
# Processing Record 31 of Set 9 | zapolyarnyy
# Processing Record 32 of Set 9 | houston
# Processing Record 33 of Set 9 | port hedland
# Processing Record 34 of Set 9 | guangyuan
# Processing Record 35 of Set 9 | great falls
# Processing Record 36 of Set 9 | santa rosa
# Processing Record 37 of Set 9 | marrakesh
# Processing Record 38 of Set 9 | sitka
# Processing Record 39 of Set 9 | singkawang
# Processing Record 40 of Set 9 | mbour
# Processing Record 41 of Set 9 | zlatoustovsk
# City not found. Skipping...
# Processing Record 42 of Set 9 | santa ana
# Processing Record 43 of Set 9 | magdagachi
# Processing Record 44 of Set 9 | ola
# Processing Record 45 of Set 9 | lagoa
# Processing Record 46 of Set 9 | oussouye
# Processing Record 47 of Set 9 | guarapari
# Processing Record 48 of Set 9 | mudbidri
# Processing Record 49 of Set 9 | isla mujeres
# Processing Record 50 of Set 9 | solnechnyy
# Processing Record 1 of Set 10 | ati
# Processing Record 2 of Set 10 | pangai
# Processing Record 3 of Set 10 | bonthe
# Processing Record 4 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 10 | toshkivka
# Processing Record 6 of Set 10 | maine-soroa
# Processing Record 7 of Set 10 | lakes entrance
# Processing Record 8 of Set 10 | sola
# Processing Record 9 of Set 10 | inhambane
# Processing Record 10 of Set 10 | asayita
# City not found. Skipping...
# Processing Record 11 of Set 10 | bodden town
# Processing Record 12 of Set 10 | khandyga
# Processing Record 13 of Set 10 | nicoya
# Processing Record 14 of Set 10 | tigil
# Processing Record 15 of Set 10 | nador
# Processing Record 16 of Set 10 | sciacca
# Processing Record 17 of Set 10 | dongsheng
# Processing Record 18 of Set 10 | dunyapur
# Processing Record 19 of Set 10 | curillo
# Processing Record 20 of Set 10 | la tuque
# Processing Record 21 of Set 10 | ixtapa
# Processing Record 22 of Set 10 | flagstaff
# Processing Record 23 of Set 10 | dali
# Processing Record 24 of Set 10 | oktyabrskoye
# Processing Record 25 of Set 10 | mayo
# Processing Record 26 of Set 10 | ouricuri
# Processing Record 27 of Set 10 | tautira
# Processing Record 28 of Set 10 | katherine
# Processing Record 29 of Set 10 | aripuana
# Processing Record 30 of Set 10 | bosaso
# Processing Record 31 of Set 10 | anloga
# Processing Record 32 of Set 10 | riyadh
# Processing Record 33 of Set 10 | plettenberg bay
# Processing Record 34 of Set 10 | daigo
# Processing Record 35 of Set 10 | nantucket
# Processing Record 36 of Set 10 | batticaloa
# Processing Record 37 of Set 10 | sevierville
# Processing Record 38 of Set 10 | lithakia
# Processing Record 39 of Set 10 | iskateley
# Processing Record 40 of Set 10 | dharmanagar
# Processing Record 41 of Set 10 | zonguldak
# Processing Record 42 of Set 10 | maryville
# Processing Record 43 of Set 10 | mastung
# Processing Record 44 of Set 10 | north platte
# Processing Record 45 of Set 10 | bom jesus
# Processing Record 46 of Set 10 | kalga
# Processing Record 47 of Set 10 | krasnoselkup
# Processing Record 48 of Set 10 | jozefow
# Processing Record 49 of Set 10 | oulainen
# Processing Record 50 of Set 10 | berezna
# Processing Record 1 of Set 11 | darnah
# Processing Record 2 of Set 11 | morros
# Processing Record 3 of Set 11 | kavieng
# Processing Record 4 of Set 11 | lucapa
# Processing Record 5 of Set 11 | mporokoso
# Processing Record 6 of Set 11 | yanchukan
# City not found. Skipping...
# Processing Record 7 of Set 11 | aitape
# Processing Record 8 of Set 11 | bilibino
# Processing Record 9 of Set 11 | filadelfia
# Processing Record 10 of Set 11 | jaragua do sul
# Processing Record 11 of Set 11 | kalianget
# Processing Record 12 of Set 11 | amga
# Processing Record 13 of Set 11 | adet
# Processing Record 14 of Set 11 | samarai
# Processing Record 15 of Set 11 | kuandian
# Processing Record 16 of Set 11 | goderich
# Processing Record 17 of Set 11 | kosh-agach
# Processing Record 18 of Set 11 | henties bay
# Processing Record 19 of Set 11 | altay
# Processing Record 20 of Set 11 | gold coast
# Processing Record 21 of Set 11 | concepcion
# Processing Record 22 of Set 11 | dalbandin
# Processing Record 23 of Set 11 | olafsvik
# Processing Record 24 of Set 11 | zamora
# Processing Record 25 of Set 11 | bayonet point
# Processing Record 26 of Set 11 | russkaya polyana
# Processing Record 27 of Set 11 | rapu-rapu
# Processing Record 28 of Set 11 | cabra
# Processing Record 29 of Set 11 | ponta delgada
# Processing Record 30 of Set 11 | shaunavon
# Processing Record 31 of Set 11 | chibombo
# Processing Record 32 of Set 11 | christchurch
# Processing Record 33 of Set 11 | thinadhoo
# Processing Record 34 of Set 11 | tecoanapa
# Processing Record 35 of Set 11 | oksfjord
# Processing Record 36 of Set 11 | cranbrook
# Processing Record 37 of Set 11 | olga
# Processing Record 38 of Set 11 | leningradskiy
# Processing Record 39 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 40 of Set 11 | esso
# Processing Record 41 of Set 11 | imbituba
# Processing Record 42 of Set 11 | ust-maya
# Processing Record 43 of Set 11 | krasnoarmeyskiy
# Processing Record 44 of Set 11 | chapais
# Processing Record 45 of Set 11 | juneau
# Processing Record 46 of Set 11 | finote selam
# Processing Record 47 of Set 11 | tarudant
# City not found. Skipping...
# Processing Record 48 of Set 11 | touros
# Processing Record 49 of Set 11 | tokzar
# City not found. Skipping...
# Processing Record 50 of Set 11 | marietta
# Processing Record 1 of Set 12 | yulara
# Processing Record 2 of Set 12 | datong
# Processing Record 3 of Set 12 | valdivia
# Processing Record 4 of Set 12 | kahului
# Processing Record 5 of Set 12 | cedral
# Processing Record 6 of Set 12 | balkhash
# Processing Record 7 of Set 12 | mundwa
# Processing Record 8 of Set 12 | west bay
# Processing Record 9 of Set 12 | bilma
# Processing Record 10 of Set 12 | kuopio
# Processing Record 11 of Set 12 | port hardy
# Processing Record 12 of Set 12 | sorland
# Processing Record 13 of Set 12 | manakara
# Processing Record 14 of Set 12 | nelidovo
# Processing Record 15 of Set 12 | korla
# Processing Record 16 of Set 12 | ayagoz
# Processing Record 17 of Set 12 | yining
# Processing Record 18 of Set 12 | soller
# Processing Record 19 of Set 12 | bandundu
# Processing Record 20 of Set 12 | key largo
# Processing Record 21 of Set 12 | mayumba
# Processing Record 22 of Set 12 | tanout
# Processing Record 23 of Set 12 | candelaria
# Processing Record 24 of Set 12 | zorritos
# Processing Record 25 of Set 12 | matay
# Processing Record 26 of Set 12 | alice town
# Processing Record 27 of Set 12 | linxia
# Processing Record 28 of Set 12 | bahia honda
# Processing Record 29 of Set 12 | camacha
# Processing Record 30 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 31 of Set 12 | eureka
# Processing Record 32 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 33 of Set 12 | hambantota
# Processing Record 34 of Set 12 | hermiston
# Processing Record 35 of Set 12 | talara
# Processing Record 36 of Set 12 | listvyagi
# Processing Record 37 of Set 12 | berdigestyakh
# Processing Record 38 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 39 of Set 12 | paragominas
# Processing Record 40 of Set 12 | morris
# Processing Record 41 of Set 12 | malanje
# Processing Record 42 of Set 12 | deputatskiy
# Processing Record 43 of Set 12 | mizan teferi
# Processing Record 44 of Set 12 | aligarh
# Processing Record 45 of Set 12 | san vicente
# Processing Record 46 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 47 of Set 12 | chardara
# Processing Record 48 of Set 12 | bandraboua
# Processing Record 49 of Set 12 | porto novo
# Processing Record 50 of Set 12 | saint-leu
# Processing Record 1 of Set 13 | amapa
# Processing Record 2 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 3 of Set 13 | corrente
# Processing Record 4 of Set 13 | buraydah
# Processing Record 5 of Set 13 | humberto de campos
# Processing Record 6 of Set 13 | maniitsoq
# Processing Record 7 of Set 13 | burica
# City not found. Skipping...
# Processing Record 8 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 9 of Set 13 | boguchany
# Processing Record 10 of Set 13 | pandan
# Processing Record 11 of Set 13 | tahe
# Processing Record 12 of Set 13 | pontes e lacerda
# Processing Record 13 of Set 13 | tiznit
# Processing Record 14 of Set 13 | muisne
# Processing Record 15 of Set 13 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 16 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 17 of Set 13 | tevaitoa
# Processing Record 18 of Set 13 | severnyy
# Processing Record 19 of Set 13 | qaqortoq
# Processing Record 20 of Set 13 | marquette
# Processing Record 21 of Set 13 | bur gabo
# City not found. Skipping...
# Processing Record 22 of Set 13 | eqbaliyeh
# Processing Record 23 of Set 13 | pundaguitan
# Processing Record 24 of Set 13 | denpasar
# Processing Record 25 of Set 13 | narasannapeta
# Processing Record 26 of Set 13 | kaeo
# Processing Record 27 of Set 13 | santiago
# Processing Record 28 of Set 13 | burg
# Processing Record 29 of Set 13 | urrao
# Processing Record 30 of Set 13 | fort smith
# Processing Record 31 of Set 13 | san angelo
# Processing Record 32 of Set 13 | voskresenskoye
# Processing Record 33 of Set 13 | selcuk
# Processing Record 34 of Set 13 | yaring
# Processing Record 35 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 13 | viedma
# Processing Record 37 of Set 13 | newton
# Processing Record 38 of Set 13 | edd
# Processing Record 39 of Set 13 | colac
# Processing Record 40 of Set 13 | mbandaka
# Processing Record 41 of Set 13 | kamariotissa
# Processing Record 42 of Set 13 | sibolga
# Processing Record 43 of Set 13 | whitefish
# Processing Record 44 of Set 13 | tabou
# Processing Record 45 of Set 13 | mackenzie
# Processing Record 46 of Set 13 | morant bay
# Processing Record 47 of Set 13 | sovetskiy
# Processing Record 48 of Set 13 | savannah bight
# Processing Record 49 of Set 13 | ancud
# Processing Record 50 of Set 13 | jiangyou
# Processing Record 1 of Set 14 | monte escobedo
# Processing Record 2 of Set 14 | darhan
# Processing Record 3 of Set 14 | almeirim
# Processing Record 4 of Set 14 | kutum
# Processing Record 5 of Set 14 | praia da vitoria
# Processing Record 6 of Set 14 | the pas
# Processing Record 7 of Set 14 | yatou
# Processing Record 8 of Set 14 | brownwood
# Processing Record 9 of Set 14 | saint-francois
# Processing Record 10 of Set 14 | rassvet
# Processing Record 11 of Set 14 | gboko
# Processing Record 12 of Set 14 | petropavl
# Processing Record 13 of Set 14 | suluq
# Processing Record 14 of Set 14 | sechura
# Processing Record 15 of Set 14 | constantine
# Processing Record 16 of Set 14 | xinxiang
# Processing Record 17 of Set 14 | esna
# Processing Record 18 of Set 14 | honningsvag
# Processing Record 19 of Set 14 | san quintin
# Processing Record 20 of Set 14 | terrak
# Processing Record 21 of Set 14 | noumea
# Processing Record 22 of Set 14 | lokomotivnyy
# Processing Record 23 of Set 14 | puerto escondido
# Processing Record 24 of Set 14 | huarmey
# Processing Record 25 of Set 14 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 14 | taoudenni
# Processing Record 27 of Set 14 | barpali
# Processing Record 28 of Set 14 | viseu
# Processing Record 29 of Set 14 | ballina
# Processing Record 30 of Set 14 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 14 | ginda
# Processing Record 32 of Set 14 | zhigansk
# Processing Record 33 of Set 14 | bintulu
# Processing Record 34 of Set 14 | tanabe
# Processing Record 35 of Set 14 | ust-tsilma
# Processing Record 36 of Set 14 | kayerkan
# Processing Record 37 of Set 14 | lawigan
# Processing Record 38 of Set 14 | russell
# Processing Record 39 of Set 14 | mayskiy
# Processing Record 40 of Set 14 | kieta
# Processing Record 41 of Set 14 | padang
# Processing Record 42 of Set 14 | port-gentil
# Processing Record 43 of Set 14 | abu samrah
# Processing Record 44 of Set 14 | troitskoye
# Processing Record 45 of Set 14 | half moon bay
# Processing Record 46 of Set 14 | fortuna
# Processing Record 47 of Set 14 | pentecoste
# Processing Record 48 of Set 14 | pemba
# Processing Record 49 of Set 14 | lalomanu
# City not found. Skipping...
# Processing Record 50 of Set 14 | brigham city
# Processing Record 1 of Set 15 | moron
# Processing Record 2 of Set 15 | oreanda
# City not found. Skipping...
# Processing Record 3 of Set 15 | tazovskiy
# Processing Record 4 of Set 15 | antofagasta
# Processing Record 5 of Set 15 | isilkul
# Processing Record 6 of Set 15 | malatya
# Processing Record 7 of Set 15 | maceio
# Processing Record 8 of Set 15 | conceicao do araguaia
# Processing Record 9 of Set 15 | mweka
# Processing Record 10 of Set 15 | orsha
# Processing Record 11 of Set 15 | carballo
# Processing Record 12 of Set 15 | kadykchan
# City not found. Skipping...
# Processing Record 13 of Set 15 | san luis
# Processing Record 14 of Set 15 | buzuluk
# Processing Record 15 of Set 15 | khormuj
# City not found. Skipping...
# Processing Record 16 of Set 15 | chunhuhub
# Processing Record 17 of Set 15 | vestmanna
# Processing Record 18 of Set 15 | coquimbo
# Processing Record 19 of Set 15 | paamiut
# Processing Record 20 of Set 15 | eyl
# Processing Record 21 of Set 15 | colinas
# Processing Record 22 of Set 15 | north bend
# Processing Record 23 of Set 15 | hilton head island
# Processing Record 24 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 25 of Set 15 | celestun
# Processing Record 26 of Set 15 | kinablangan
# Processing Record 27 of Set 15 | kiunga
# Processing Record 28 of Set 15 | kuliyapitiya
# Processing Record 29 of Set 15 | asaba
# Processing Record 30 of Set 15 | umm jarr
# City not found. Skipping...
# Processing Record 31 of Set 15 | canandaigua
# Processing Record 32 of Set 15 | klishkivtsi
# Processing Record 33 of Set 15 | kendari
# Processing Record 34 of Set 15 | ocho rios
# Processing Record 35 of Set 15 | garmsar
# Processing Record 36 of Set 15 | hit
# Processing Record 37 of Set 15 | sakaiminato
# Processing Record 38 of Set 15 | boissevain
# Processing Record 39 of Set 15 | atbasar
# Processing Record 40 of Set 15 | warrnambool
# Processing Record 41 of Set 15 | broken hill
# Processing Record 42 of Set 15 | ngukurr
# City not found. Skipping...
# Processing Record 43 of Set 15 | kastamonu
# Processing Record 44 of Set 15 | totskoye
# Processing Record 45 of Set 15 | sur
# Processing Record 46 of Set 15 | asyut
# Processing Record 47 of Set 15 | saint anthony
# Processing Record 48 of Set 15 | andenes
# Processing Record 49 of Set 15 | tilichiki
# Processing Record 50 of Set 15 | calabozo
# Processing Record 1 of Set 16 | pokhara
# Processing Record 2 of Set 16 | hovd
# Processing Record 3 of Set 16 | kuusamo
# Processing Record 4 of Set 16 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 16 | shelburne
# Processing Record 6 of Set 16 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 16 | plerin
# Processing Record 8 of Set 16 | veraval
# Processing Record 9 of Set 16 | zaysan
# Processing Record 10 of Set 16 | novaya igirma
# Processing Record 11 of Set 16 | wewak
# Processing Record 12 of Set 16 | fukue
# Processing Record 13 of Set 16 | roebourne
# Processing Record 14 of Set 16 | taltal
# Processing Record 15 of Set 16 | sabha
# Processing Record 16 of Set 16 | inhuma
# Processing Record 17 of Set 16 | crowley
# Processing Record 18 of Set 16 | lichinga
# Processing Record 19 of Set 16 | ponca city
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(city_data)
# Out:
# [{'City': 'Puerto Ayora', 'Lat': -0.7393, 'Lng': -90.3518, 'Max Temp': 80.56, 'Humidity': 84, 'Cloudiness': 82, 'Wind Speed': 5.99, 'Country': 'EC', 'Current Description': 'broken clouds'}, {'City': 'Faanui', 'Lat': -16.4833, 'Lng': -151.75, 'Max Temp': 79.92, 'Humidity': 77, 'Cloudiness': 91, 'Wind Speed': 14.7, 'Country': 'PF', 'Current Description': 'light rain'}, {'City': 'Kapaa', 'Lat': 22.0752, 'Lng': -159.319, 'Max Temp': 69.78, 'Humidity': 88, 'Cloudiness': 1, 'Wind Speed': 3.49, 'Country': 'US', 'Current Description': 'clear sky'}, {'City': 'New Norfolk', 'Lat': -42.7826, 'Lng': 147.0587, 'Max Temp': 39.7, 'Humidity': 85, 'Cloudiness': 33, 'Wind Speed': 2.98, 'Country': 'AU', 'Current Description': 'scattered clouds'}, {'City': 'Umm Kaddadah', 'Lat': 13.6017, 'Lng': 26.6876, 'Max Temp': 102.49, 'Humidity': 10, 'Cloudiness': 36, 'Wind Speed': 10.83, 'Country': 'SD', 'Current Description': 'scattered clouds'}, {'City': 'Castro', 'Lat': -24.7911, 'Lng': -50.0119, 'Max Temp': 57.18, 'Humidity': 97, 'Cloudiness': 100, 'Wind Speed': 2.3, 'Country': 'BR', 'Current Description': 'overcast clouds'}, {'City': 'Miles City', 'Lat': 46.4083, 'Lng': -105.8406, 'Max Temp': 63.57, 'Humidity': 48, 'Cloudiness': 1, 'Wind Speed': 5.75, 'Country': 'US', 'Current Description': 'clear sky'}, {'City': 'Praya', 'Lat': 14.9215, 'Lng': -23.5087, 'Max Temp': 82.94, 'Humidity': 54, 'Cloudiness': 20, 'Wind Speed': 16.11, 'Country': 'CV', 'Current Description': 'few clouds'}, {'City': 'Te Anau', 'Lat': -45.4167, 'Lng': 167.7167, 'Max Temp': 47.77, 'Humidity': 96, 'Cloudiness': 100, 'Wind Speed': 5.57, 'Country': 'NZ', 'Current Description': 'overcast clouds'}, {'City': 'Chimbote', 'Lat': -9.0853, 'Lng': -78.5783, 'Max Temp': 69.85, 'Humidity': 76, 'Cloudiness': 55, 'Wind Speed': 8.03, 'Country': 'PE', 'Current Description': 'broken clouds'}, {'City': 'Kenai', 'Lat': 60.5544, 'Lng': -151.2583, 'Max Temp': 50.02, 'Humidity': 84, 'Cloudiness': 90, 'Wind Speed': 12.66, 'Country': 'US', 'Current Description': 'overcast clouds'}, {'City': 'Labuhan', 'Lat': -6.8844, 'Lng': 112.2051, 'Max Temp': 79.45, 'Humidity': 82, 'Cloudiness': 100, 'Wind Speed': 3.98, 'Country': 'ID', 'Current Description': 'overcast clouds'}, {'City': 'Busselton', 'Lat': -33.65, 'Lng': 115.3333, 'Max Temp': 54.09, 'Humidity': 70, 'Cloudiness': 100, 'Wind Speed': 15.28, 'Country': 'AU', 'Current Description': 'overcast clouds'}, {'City': 'Kimbe', 'Lat': -5.5502, 'Lng': 150.1429, 'Max Temp': 75.65, 'Humidity': 95, 'Cloudiness': 42, 'Wind Speed': 5.53, 'Country': 'PG', 'Current Description': 'scattered clouds'}, {'City': 'Souillac', 'Lat': -20.5167, 'Lng': 57.5167, 'Max Temp': 74.35, 'Humidity': 78, 'Cloudiness': 10, 'Wind Speed': 7.11, 'Country': 'MU', 'Current Description': 'clear sky'}, {'City': 'Rikitea', 'Lat': -23.1203, 'Lng': -134.9692, 'Max Temp': 74.25, 'Humidity': 83, 'Cloudiness': 100, 'Wind Speed': 17.16, 'Country': 'PF', 'Current Description': 'moderate rain'}, {'City': 'Arraial Do Cabo', 'Lat': -22.9661, 'Lng': -42.0278, 'Max Temp': 78.66, 'Humidity': 78, 'Cloudiness': 75, 'Wind Speed': 11.5, 'Country': 'BR', 'Current Description': 'broken clouds'}, {'City': 'Punta Arenas', 'Lat': -53.15, 'Lng': -70.9167, 'Max Temp': 37.51, 'Humidity': 56, 'Cloudiness': 40, 'Wind Speed': 9.19, 'Country': 'CL', 'Current Description': 'scattered clouds'}, {'City': 'San Patricio', 'Lat': 28.017, 'Lng': -97.5169, 'Max Temp': 85.86, 'Humidity': 59, 'Cloudiness': 12, 'Wind Speed': 13.42, 'Country': 'US', 'Current Description': 'few clouds'}, {'City': 'Albany', 'Lat': 42.6001, 'Lng': -73.9662, 'Max Temp': 49.35, 'Humidity': 90, 'Cloudiness': 100, 'Wind Speed': 4.61, 'Country': 'US', 'Current Description': 'moderate rain'}, {'City': 'Spring Hill', 'Lat': 28.4769, 'Lng': -82.5255, 'Max Temp': 88.02, 'Humidity': 55, 'Cloudiness': 1, 'Wind Speed': 3, 'Country': 'US', 'Current Description': 'clear sky'}, {'City': 'Mehamn', 'Lat': 71.0357, 'Lng': 27.8492, 'Max Temp': 42.98, 'Humidity': 81, 'Cloudiness ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora  -0.7393  -90.3518     80.56        84          82
# 1        Faanui -16.4833 -151.7500     79.92        77          91
# 2         Kapaa  22.0752 -159.3190     69.78        88           1
# 3   New Norfolk -42.7826  147.0587     39.70        85          33
# 4  Umm Kaddadah  13.6017   26.6876    102.49        10          36
# 5        Castro -24.7911  -50.0119     57.18        97         100
# 6    Miles City  46.4083 -105.8406     63.57        48           1
# 7         Praya  14.9215  -23.5087     82.94        54          20
# 8       Te Anau -45.4167  167.7167     47.77        96         100
# 9      Chimbote  -9.0853  -78.5783     69.85        76          55
#
#    Wind Speed Country Current Description
# 0        5.99      EC       broken clouds
# 1       14.70      PF          light rain
# 2        3.49      US           clear sky
# 3        2.98      AU    scattered clouds
# 4       10.83      SD    scattered clouds
# 5        2.30      BR     overcast clouds
# 6        5.75      US           clear sky
# 7       16.11      CV          few clouds
# 8        5.57      NZ     overcast clouds
# 9        8.03      PE       broken clouds

# %%
# re-order column
new_column_order = ["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Puerto Ayora      EC  -0.7393  -90.3518     80.56        84          82
# 1        Faanui      PF -16.4833 -151.7500     79.92        77          91
# 2         Kapaa      US  22.0752 -159.3190     69.78        88           1
# 3   New Norfolk      AU -42.7826  147.0587     39.70        85          33
# 4  Umm Kaddadah      SD  13.6017   26.6876    102.49        10          36
# 5        Castro      BR -24.7911  -50.0119     57.18        97         100
# 6    Miles City      US  46.4083 -105.8406     63.57        48           1
# 7         Praya      CV  14.9215  -23.5087     82.94        54          20
# 8       Te Anau      NZ -45.4167  167.7167     47.77        96         100
# 9      Chimbote      PE  -9.0853  -78.5783     69.85        76          55
#
#    Wind Speed Current Description
# 0        5.99       broken clouds
# 1       14.70          light rain
# 2        3.49           clear sky
# 3        2.98    scattered clouds
# 4       10.83    scattered clouds
# 5        2.30     overcast clouds
# 6        5.75           clear sky
# 7       16.11          few clouds
# 8        5.57     overcast clouds
# 9        8.03       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "weather_database/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
